# %%
import warnings
warnings.simplefilter("ignore")

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
dataset =pd.read_csv("election.csv")
dataset.head()
# Out:
#   Location.County  Location.State Location.State Abbreviation  \
# 0       Abbeville  South Carolina                          SC
# 1           Abbot           Maine                          ME
# 2        Abington   Massachusetts                          MA
# 3          Acadia       Louisiana                          LA
# 4        Accomack        Virginia                          VA
#
#    Vote Data.Ben Carson.Number of Votes Vote Data.Ben Carson.Party  \
# 0                                   305                 Republican
# 1                                     0                 Republican
# 2                                    53                 Republican
# 3                                     0                 Republican
# 4                                   411                 Republican
#
#    Vote Data.Ben Carson.Percent of Votes  \
# 0                                    8.3
# 1                                    0.0
# 2                                    2.5
# ...

# %%
dataset.shape
# Out:
# (4216, 10)

# %%
dataset
# Out:
#      Location.County  Location.State Location.State Abbreviation  \
# 0          Abbeville  South Carolina                          SC
# 1              Abbot           Maine                          ME
# 2           Abington   Massachusetts                          MA
# 3             Acadia       Louisiana                          LA
# 4           Accomack        Virginia                          VA
# ...              ...             ...                         ...
# 4211            Yuma         Arizona                          AZ
# 4212            Yuma        Colorado                          CO
# 4213          Zapata           Texas                          TX
# 4214          Zavala           Texas                          TX
# 4215         Ziebach    South Dakota                          SD
#
#       Vote Data.Ben Carson.Number of Votes Vote Data.Ben Carson.Party  \
# 0                                      305                 Republican
# ...

# %%
dataset.plot(x='Vote Data.Ben Carson.Number of Votes', y='Vote Data.Ben Carson.Percent of Votes',style='o' )    
plt.title('Vote Data.Ben Carson.Number of Votes vs Vote Data.Ben Carson.Percent of Votes')    
plt.xlabel('Vote Data.Ben Carson.Number of Votes')    
plt.ylabel('Vote Data.Ben Carson.Percent of Votes')    
plt.show()

# %%
dataset.plot(x='Vote Data.Bernie Sanders.Number of Votes', y='Vote Data.Bernie Sanders.Percent of Votes',style='o' )    
plt.title('Vote Data.Bernie Sanders.Number of Votes % vs Vote Data.Bernie Sanders.Percent of Votes')    
plt.xlabel('Vote Data.Bernie Sanders.Number of Votes')    
plt.ylabel('Vote Data.Bernie Sanders.Percent of Votes')    
plt.show()

# %%
new_set = dataset.drop(['Location.County','Location.State','Location.State Abbreviation','Vote Data.Ben Carson.Party', 'Vote Data.Bernie Sanders.Party', 'Vote Data.Carly Fiorina.Number of Votes'], axis=1)

# %%
new_set
# Out:
#       Vote Data.Ben Carson.Number of Votes  \
# 0                                      305
# 1                                        0
# 2                                       53
# 3                                        0
# 4                                      411
# ...                                    ...
# 4211                                     0
# 4212                                     0
# 4213                                     4
# 4214                                     0
# 4215                                     0
#
#       Vote Data.Ben Carson.Percent of Votes  \
# 0                                       8.3
# 1                                       0.0
# 2                                       2.5
# 3                                       0.0
# 4                                       9.5
# ...                                     ...
# 4211                                    0.0
# 4212                                    0.0
# ...

# %%
new_set.head()
# Out:
#    Vote Data.Ben Carson.Number of Votes  \
# 0                                   305
# 1                                     0
# 2                                    53
# 3                                     0
# 4                                   411
#
#    Vote Data.Ben Carson.Percent of Votes  \
# 0                                    8.3
# 1                                    0.0
# 2                                    2.5
# 3                                    0.0
# 4                                    9.5
#
#    Vote Data.Bernie Sanders.Number of Votes  \
# 0                                       312
# 1                                         1
# 2                                      1352
# 3                                      1087
# 4                                       682
#
#    Vote Data.Bernie Sanders.Percent of Votes
# 0                                       17.0
# 1                                      100.0
# 2                                       53.4
# ...

# %%
x=new_set.iloc[:,0]

# %%
x.shape
# Out:
# (4216,)

# %%
x=new_set.iloc[:,0].values.reshape(-1,1)

# %%
x.shape
# Out:
# (4216, 1)

# %%
x
# Out:
# array([[305],
#        [  0],
#        [ 53],
#        ...,
#        [  4],
#        [  0],
#        [  0]], dtype=int64)

# %%
y = new_set.iloc[:,1]

# %%
y.shape
# Out:
# (4216,)

# %%
y=new_set.iloc[:,1].values.reshape(-1,1)

# %%
y
# Out:
# array([[8.3],
#        [0. ],
#        [2.5],
#        ...,
#        [4.7],
#        [0. ],
#        [0. ]])

# %%
plt.scatter(x,y)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
x_train.shape
# Out:
# (3372, 1)

# %%
x_test.shape
# Out:
# (844, 1)

# %%
y_train.shape
# Out:
# (3372, 1)

# %%
y_test.shape
# Out:
# (844, 1)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test)

# %%
y_pred
# Out:
# array([[ 2.04975854],
#        [ 2.04975854],
#        [ 2.04975854],
#        [ 2.04975854],
#        [ 3.47246228],
#        [ 2.23616702],
#        [ 2.63255285],
#        [ 2.04975854],
#        [ 2.09689632],
#        [ 2.04975854],
#        [ 2.04975854],
#        [ 2.04975854],
#        [ 2.04975854],
#        [ 5.2379862 ],
#        [ 2.04975854],
#        [ 2.06047167],
#        [ 2.04975854],
#        [ 3.4081835 ],
#        [ 2.04975854],
#        [ 2.04975854],
#        [ 2.24902277],
#        [ 2.04975854],
#        [ 2.04975854],
#        [ 4.08525335],
#        [ 2.53184942],
#        [ 2.04975854],
#        [ 2.26616378],
#        [ 2.12046521],
#        [ 2.04975854],
#        [ 2.0540438 ],
#        [ 2.17831611],
#        [ 2.04975854],
#        [ 3.55388208],
#        [ 2.04975854],
#        [ 2.201885  ],
#        [ 2.69254638],
#        [ 2.04975854],
#        [ 2.04975854],
#        [ 2.42900337],
#        [ 2.81467607],
#        [ 2.14831934],
# ...

# %%
plt.scatter(x,y, color = 'yellow')
plt.plot(x_test,y_pred, color = 'blue')
